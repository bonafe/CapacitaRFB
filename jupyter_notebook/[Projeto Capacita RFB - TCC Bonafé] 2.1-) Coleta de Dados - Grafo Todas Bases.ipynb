# %%
import os
from os import listdir
from os.path import isfile, join

import pandas as pd

# %%
import httpimport

with httpimport.remote_repo(['visualizador_dataframes'],'https://bonafe.github.io/CienciaDadosPython/src/componentes/'):
    from visualizador_dataframes import VisualizadorDataFrames

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# Entrega 2022 do Sistema SA3
df_acoes = pd.read_csv( "z:/bases_capacita/projeto_capacita/sa3/entrega_2022/2022_06_01-acoes_capacitacao.csv", index_col=None, header=0)
df_acoes.name = "acoes"

df_agentes_realizadores = pd.read_csv("z:/bases_capacita/projeto_capacita/sa3/entrega_2022/2022_06_01-agentes_realizadores.csv", index_col=None, header=0)
df_agentes_realizadores.name = "agentes_realizadores"

df_conteudo_programatico_acoes_capacitacao = pd.read_csv("z:/bases_capacita/projeto_capacita/sa3/entrega_2022/2022_06_01-conteudo_programatico_acoes_capacitacao.csv", index_col=None, header=0)
df_conteudo_programatico_acoes_capacitacao.name = "conteudo_programatico_acoes_capacitacao"

df_formacao_siape = pd.read_csv("z:/bases_capacita/projeto_capacita/sa3/entrega_2022/2022_06_02-formacao_academica_servidor_base_siape.csv", index_col=None, header=0)
df_formacao_siape.name = "formacao_siape"

df_formacao_migrada = pd.read_csv("z:/bases_capacita/projeto_capacita/sa3/entrega_2022/2022_06_02-formacao_academica_servidor_migrada.csv", index_col=None, header=0)
df_formacao_migrada.name = "formacao_migrada"

df_instrutores = pd.read_csv("z:/bases_capacita/projeto_capacita/sa3/entrega_2022/2022_06_02-instrutores.csv", index_col=None, header=0)
df_instrutores.name = "instrutores"

df_rcd = pd.read_csv("z:/bases_capacita/projeto_capacita/sa3/entrega_2022/2022_06_02-rcd.csv", index_col=None, header=0)
df_rcd.name = "rcd"

df_capacitacao_servidor = pd.read_csv("z:/bases_capacita/projeto_capacita/sa3/entrega_2022/2022_06_02-acoes_capacitacao_servidor.csv", index_col=None, header=0)
df_capacitacao_servidor.name = "capacitacao_servidor"



# Entrega 2021 do Sistema SA3
df_acoes_2021 = pd.read_csv( "z:/bases_capacita/projeto_capacita/sa3/entrega_2022/2022_06_01-acoes_capacitacao.csv", index_col=None, header=0)
df_acoes_2021.name = "acoes"

df_agentes_realizadores_2021 = pd.read_csv("z:/bases_capacita/projeto_capacita/sa3/entrega_2021/2022_06_01-agentes_realizadores.csv", index_col=None, header=0)
df_agentes_realizadores_2021.name = "agentes_realizadores"

df_conteudo_programatico_acoes_capacitacao_2021 = pd.read_csv("z:/bases_capacita/projeto_capacita/sa3/entrega_2021/2022_06_01-conteudo_programatico_acoes_capacitacao.csv", index_col=None, header=0)
df_conteudo_programatico_acoes_capacitacao_2021.name = "conteudo_programatico_acoes_capacitacao"

df_formacao_siape_2021 = pd.read_csv("z:/bases_capacita/projeto_capacita/sa3/entrega_2021/2022_06_01-formacao_academica_servidor-base_siape.csv", index_col=None, header=0)
df_formacao_siape_2021.name = "formacao_siape"

df_formacao_migrada_2021 = pd.read_csv("z:/bases_capacita/projeto_capacita/sa3/entrega_2021/2022_06_01-formacao_academica_servidor-base_migrada.csv", index_col=None, header=0)
df_formacao_migrada_2021.name = "formacao_migrada"

df_instrutores_2021 = pd.read_csv("z:/bases_capacita/projeto_capacita/sa3/entrega_2021/2022_06_01-instrutores.csv", index_col=None, header=0)
df_instrutores_2021.name = "instrutores"

df_rcd_2021 = pd.read_csv("z:/bases_capacita/projeto_capacita/sa3/entrega_2021/2022_06_01-rcd.csv", index_col=None, header=0)
df_rcd_2021.name = "rcd"

df_capacitacao_servidor_2021 = pd.read_csv("z:/bases_capacita/projeto_capacita/sa3/entrega_2021/2022_06_02-acoes_capacitacao_servidor.csv", index_col=None, header=0)
df_capacitacao_servidor_2021.name = "capacitacao_servidor"

df_competencias_acoes = pd.read_csv("z:/bases_capacita/projeto_capacita/sa3/entrega_2021/2022_06_01-competencias_acoes_capacitacao.csv", index_col=None, header=0)
df_competencias_acoes.name = "competencias_acoes"

df_competencias = pd.read_csv("z:/bases_capacita/projeto_capacita/sa3/entrega_2021/2022_06_01-competencias_rfb.csv", index_col=None, header=0)
df_competencias.name = "competencias"

df_diagnostico_competencias_servidor = pd.read_csv("z:/bases_capacita/projeto_capacita/sa3/entrega_2021/2022_06_02-diagnostico_competencias_servidor_rfb.csv", index_col=None, header=0)
df_diagnostico_competencias_servidor.name = "diagnostico_competencias_servidor"

df_diagnostico_competencias_nivel = pd.read_csv("z:/bases_capacita/projeto_capacita/sa3/entrega_2021/2022_06_02-diagnostico_competencias_nivel_rfb.csv", index_col=None, header=0)
df_diagnostico_competencias_nivel.name = "diagnostico_competencias_nivel"

df_ciclos_competencias = pd.read_csv("z:/bases_capacita/projeto_capacita/sa3/entrega_2021/2022_06_01-ciclos_competencias_rfb.csv", index_col=None, header=0)
df_ciclos_competencias.name = "ciclos_competencias"



# Extração Sistema Aris
df_processos_trabalho = pd.read_csv("z:/bases_capacita/projeto_capacita/aris/2022_06_01-processos_trabalho_rfb.csv", index_col=None, header=0)
df_processos_trabalho.name = "processos_trabalho"

# %%
dfs_originais = [
    df_acoes, 
    df_capacitacao_servidor, 
    df_instrutores, 
    df_rcd, 
    df_agentes_realizadores,  
    df_conteudo_programatico_acoes_capacitacao, 
    df_competencias_acoes, 
    df_formacao_siape, 
    df_formacao_migrada,
    df_processos_trabalho, 
    df_competencias,
    df_diagnostico_competencias_servidor,
    df_diagnostico_competencias_nivel,
    df_ciclos_competencias
]

dfs = []

for df_original in dfs_originais:
    
    df = None
    
    try:
        df = df_original.copy()
    except:
        df = df_original.copy()
        
    if hasattr(df_original,"name"):
        df.name = df_original.name        
    
    dfs.append(df)

# %%
visualizador = VisualizadorDataFrames(dfs)

# %%
dicionario_datasets = {                
    "acoes":{
        "titulo":"Ações de Capacitação",
        "sistema":"SA3"                        
    },

    "capacitacao_servidor":{
        "titulo":"Ações de Capacitação do Servidor",
        "sistema":"SA3"
    },

    "instrutores":{
        "titulo":"Intrutores",
        "sistema":"SA3"
    },

    "rcd":{
        "titulo":"RCD",
        "sistema":"SA3"
    },

    "agentes_realizadores":{
        "titulo":"Agentes Realizadores",
        "sistema":"SA3"
    },

    "conteudo_programatico_acoes_capacitacao":{
        "titulo":"Conteúdo Programático",
        "sistema":"SA3"
    },

    "competencias_acoes":{
        "titulo":"Relação Competências/Ações de Capacitação",
        "sistema":"SA3"            
    },       
    
    "formacao_siape":{
        "titulo":"Formação Acadêmica Servidor Siape",
        "sistema":"Siape/SA3"            
    },
    
    "formacao_migrada":{
        "titulo":"Formação Acadêmica Servidor Migrada",
        "sistema":"Siape/SA3"            
    } ,
    
    "processos_trabalho":{
        "titulo":"Processos de Trabalho RFB",
        "sistema":"Aris"
    },
    
    "competencias":{
        "titulo":"Competências RFB",
        "sistema":"SA3"
    },   
    
    "diagnostico_competencias_servidor":{
        "titulo":"Diagnóstico Competências Servidor",
        "sistema":"SA3"
    },
    
    "diagnostico_competencias_nivel":{
        "titulo":"Diagnóstico Competências Nível",
        "sistema":"SA3"
    },
    
    "ciclos_competencias":{
        "titulo":"Ciclos Competências",
        "sistema":"SA3"
    }
}

# %%
metadados_capacita = visualizador.gerarMetadados(dicionario_datasets)

# %% [markdown]
# # ATENÇÃO: Aguarde, o grafo pode demorar um pouco para renderizar

# %%
visualizador.exibirGrafoBases(metadados_capacita, mostrarDetalhes=False)

# %%
import json
from datetime import datetime

def prefixoData(data):
    return data.strftime("%Y_%m_%d")

json_string_metadados_bases = json.dumps(metadados_capacita)

# Using a JSON string
with open(f'./dados/{prefixoData(datetime.now())}_metadados_bases_capacita.json', 'w') as outfile:
    outfile.write(json_string_metadados_bases)
