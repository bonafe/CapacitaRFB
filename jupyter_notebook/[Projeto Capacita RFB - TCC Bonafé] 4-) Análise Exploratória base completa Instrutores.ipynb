# %%
import os
from os import listdir
from os.path import isfile, join

import re

import numpy as np

from datetime import datetime

import json

import pandas as pd

from IPython.display import display, Markdown

import matplotlib.pyplot as plt

# %%
import httpimport

with httpimport.remote_repo(['visualizador_dataframes', 'ferramentas_linguagem_natural'],'https://bonafe.github.io/CienciaDadosPython/src/componentes/'):
    from ferramentas_linguagem_natural import FerramentasLinguagemNatural
    from visualizador_dataframes import VisualizadorDataFrames

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 10000)

# %%
df_instrutores = pd.read_csv("z:/bases_capacita/projeto_capacita/tcc_bonafe/2022_06_30-instrutores_acoes-capacitacao_conteudo-programatico_anonimizado.csv", index_col=None, header=0)
df_instrutores.name = "instrutores"

# %%
df_instrutores.info()

# %%
visualizador = VisualizadorDataFrames(df_instrutores)
metadados_capacita = visualizador.gerarMetadados()
visualizador.exibirGrafoBases(metadados_capacita, mostrarDetalhes=False)

# %%
visualizador.exibirMetricas("instrutores", log=False)

# %%
df_instrutores[~df_instrutores["conteudo_programatico"].isna()][["conteudo_programatico", "titulo_acao", "objetivo_projeto", "nome_curso"]].sample(3)

# %%
df_instrutores["data_inicio"]

# %%
ax = df_instrutores.value_counts("tipo_competencia").to_frame().plot.bar(legend=False, figsize=(16,10))
ax.bar_label(ax.containers[0])

# %%
df_instrutores["tipo_competencia"].count()

# %%
ax = df_instrutores.value_counts("tipo").to_frame().plot.bar(legend=False, figsize=(16,10))
ax.bar_label(ax.containers[0])

# %%
ax = df_instrutores.value_counts("titulo_competencia").to_frame().head(20).plot.bar(legend=False, figsize=(16,10))
ax.bar_label(ax.containers[0])

# %%
df_instrutores.value_counts("titulo_competencia").to_frame().count()

# %%
df_instrutores["titulo_competencia"].count()

# %%
ax = df_instrutores.value_counts("ano_evento").to_frame().sort_index().plot.bar(legend=False, figsize=(16,10))
ax.bar_label(ax.containers[0])

# %%
df_instrutores['ano_evento'].count()

# %%
ax = df_instrutores.value_counts("ano_conclusao").to_frame().sort_index().plot.bar(legend=False, figsize=(16,10))
ax.bar_label(ax.containers[0])

# %%
df_instrutores['ano_conclusao'].count()

# %%
df_instrutores["carga_horaria"].describe()

# %%
FerramentasLinguagemNatural.exibirCorpora(df_instrutores, 'conteudo_programatico')

# %%
df_instrutores['conteudo_programatico'].count()

# %%
df_instrutores['conteudo_programatico'].shape

# %%
5573/34753

# %%
FerramentasLinguagemNatural.exibirCorpora(df_instrutores, 'titulo_acao')

# %%
FerramentasLinguagemNatural.exibirCorpora(df_instrutores, 'nome_curso')

# %%
34487/34753
# Out:
# 0.9923459845193221

# %%
FerramentasLinguagemNatural.exibirCorpora(df_instrutores, 'objetivo_projeto')
# Out:
# # <center>Corpora da coluna *objetivo_projeto*</center>
# Número de registros: ***34752***
# ## <center>Palavras encontradas na coluna *objetivo_projeto*</center>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 FerramentasLinguagemNatural.exibirCorpora(df_instrutores, 'objetivo_projeto')
#
# File <string>:149, in exibirCorpora(df, coluna)
#
# File <string>:265, in exibirHistograma(df, campo, titulo, label)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\pyplot.py:368, in show(*args, **kwargs)
#     324 """
#     325 Display all open figures.
#     326
#    (...)
#     365 explicitly there.
#     366 """
#     367 _warn_if_gui_out_of_main_thread()
# --> 368 return _backend_mod.show(*args, **kwargs)
#
# File ~\Anaconda3\envs\capacita2\lib\site-packages\matplotlib_inline\backend_inline.py:41, in show(close, block)
# ...
